# %% [markdown]
# # Introduction to AI Chapter 1

# %% [markdown]
# Artificial Intelligence(AI) - is ability of a computer program or a machine to think and learn. Its also a field of study that tries to make a computer smart.
#
# ## 5) citata
