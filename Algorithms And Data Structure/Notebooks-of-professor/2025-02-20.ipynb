# %%
4 + 5
# Out:
# 9

# %%
4 + 7
# Out:
# 11

# %%
a = 4
b = 10

# %%
print(a + b)
# Out:
# 14

# %%
b = 5

# %%
print(a + b)
# Out:
# 9

# %%
msg = 'Hello'

# %%
print(msg)
# Out:
# Hello

# %%
10+10
# Out:
# 20

# %%
'10' + '10'
# Out:
# '1010'

# %%
x = 20

# %%
x = 'Bye'

# %%
print(x)
# Out:
# Bye

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
y = 12
print(type(y))
# Out:
# <class 'int'>

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
z = 12.34
print(type(z))
# Out:
# <class 'float'>

# %%
mystring1 = 'Hello everyone'
mystring2 = "Hello everyone"

# %%
print(type(mystring1))
print(type(mystring2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
mystring1 == mystring2
# Out:
# True

# %%
print(z)
# Out:
# 12.34

# %%
z = z + 0.4
print(z)
# Out:
# 12.74

# %%
1mystring = 'Hello'
# Out:
#   Cell In[24], line 1
#     1mystring = 'Hello'
#     ^
# SyntaxError: invalid decimal literal

# %%
Mystring1 = 'ciao'

# %%
print(Mystring1)
print(mystring1)
# Out:
# ciao
# Hello everyone

# %%
z-y
# Out:
# 0.7400000000000002

# %%
z_y = 100

# %%
print(z_y)
# Out:
# 100

# %%
print(Mystring1 + ' ' + mystring1)
# Out:
# ciao Hello everyone

# %%
print(Mystring1)
print()
print(mystring1)
# Out:
# ciao
#
# Hello everyone

# %%
print(Mystring1, 'a\nb')
print(mystring1)
# Out:
# ciao a
# b
# Hello everyone

# %%
Mystring2 = ' '

# %%
print(z_y)
print(Mystring1)
print(mystring1)
print(y_z)
# Out:
# 100
# ciao
# Hello everyone
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 print(Mystring1)
#       3 print(mystring1)
# ----> 4 print(y_z)
#
# NameError: name 'y_z' is not defined

# %%
expr1 = 4 + 5 * 6
print(expr1)
# Out:
# 34

# %%
expr2 = (4 + 5) * 6
print(expr2)
# Out:
# 54

# %% [markdown]
# $$ \frac{10}{2\cdot 4}$$

# %%
expr3 = 10 / 2 * 4
print(expr3)
# Out:
# 20.0

# %%
10/(2 * 4)
# Out:
# 1.25

# %%
10 / 2 / 4
# Out:
# 1.25

# %% [markdown]
# $$2^4$$

# %%
2**4
# Out:
# 16

# %%
import math

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.pow(2,4)
# Out:
# 16.0

# %%
def sqrt(number):
    """
    This is a multiline comment.
    This function is just to show an example of 
    home-made function bearing the same of math.sqrt.
    Using the module name no name conflict emerges.
    """
    x = number*2 #an example of wrong sqrt
    return x

# %%
sqrt(100)
# Out:
# 200

# %% [markdown]
# $$ \frac{360}{2 \pi}$$

# %%
360/2*math.pi
# Out:
# 565.4866776461628

# %%
360/2/math.pi
# Out:
# 57.29577951308232
