# %% [markdown]
# $$ F = G\frac{m_1 m_2}{d^2}
# $$

# %%
str1 = 'Hello everyone, 356 students of Data Analysis'
for john in str1:
    print(john.upper(), end = '_')
# Out:
# H_E_L_L_O_ _E_V_E_R_Y_O_N_E_,_ _3_5_6_ _S_T_U_D_E_N_T_S_ _O_F_ _D_A_T_A_ _A_N_A_L_Y_S_I_S_

# %%
a = 10
b = '10'
c = 20
d = '20'

# %%
print(a+c)
print(b+d)
# Out:
# 30
# 1020

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(a)+b
# Out:
# '1010'

# %%
a + int(b)
# Out:
# 20

# %%
e = 10.0

# %%
f = str(e)

# %%
int(f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 int(f)
#
# ValueError: invalid literal for int() with base 10: '10.0'

# %%
g = float(e)
